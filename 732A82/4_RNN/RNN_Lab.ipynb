# %% [markdown]
# # RNN Machine Translation Laboration

# %% [markdown]
# In this lab, your task is to build a sequence-to-sequence model, using recurrent neural networks, that translates short sentences from Swedish into English.

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # Tensorflow is quite chatty; filter out warnings

# %%
import tensorflow as tf
import tf_keras as keras
from tf_keras import layers

# %% [markdown]
# ### Check that Tensorflow uses a GPU _(optional)_
#
# Training the models in this notebook can be sped up significantly with a GPU.  The following cell can be used to check if the GPU is set up correctly.  If you run on CPU, you can either run or just ignore this cell.

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# The GPU id to use, usually either "0" or "1"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

if tf.config.list_physical_devices("GPU"):
    print("✓ Tensorflow has detected a GPU.")
    import shutil
    if not shutil.which("ptxas"):
        print("\n✗ Command 'ptxas' not found in path -- you might have to install `cudatoolkit-dev`")
    if not "XLA_FLAGS" in os.environ:
        print("\n✗ XLA_FLAGS not set. If you encounter errors during training, you might have to set")
        print("        XLA_FLAGS=\"--xla_gpu_cuda_data_dir=$CONDA_PREFIX/lib/\"")
    
    # Allow growth of GPU memory, otherwise it will always look like all the memory is being used
    physical_devices = tf.config.experimental.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], True) 
else:
    print("✗ Tensorflow has NOT detected a GPU.")
    print()
    print("For GPU support, visit: <https://www.tensorflow.org/install/pip>")
# Out:
# ✗ Tensorflow has NOT detected a GPU.
#
# For GPU support, visit: <https://www.tensorflow.org/install/pip>

# %% [markdown]
# ## Problem Specification
#
# Your task in this assignment is to:
#
# 1. Build an encoder—decoder model based on recurrent neural networks.
# 2. Train this model on the provided training data, a collection of parallel Swedish–English sentences.
# 3. Evaluate the performance of this model on the provided test data.

# %% [markdown]
# ### The data: Swedish–English Anki corpus

# %% [markdown]
# The data in this lab consists of bilingual Swedish–English sentence pairs from the [Tatoeba Project](https://tatoeba.org/en) as collected by [Anki](http://www.manythings.org/anki/).  These are comparatively short sentences, suitable for language learners, and therefore also well-suited for building a small machine translation model. Here are some example sentences from the training set:

# %%
with open("en-sv-train.txt", "rt") as f:
    for i, line in enumerate(f):
        pair = [sent for sent in line.rstrip().split("\t")]
        print(pair)
        if i > 2:
            break
# Out:
# ['i returned to japan .', 'jag återvände till japan .']
# ['i love her .', 'jag älskar henne .']
# ["this is tom ' s school .", 'detta är toms skola .']
# ['i can hardly stand .', 'jag kan knappt stå .']

# %% [markdown]
# Each line in the data files consists of an English–Swedish sentence pair. The sentences are already lower-cased and pre-tokenized (using the [toktok tokenizer from NLTK](https://www.nltk.org/howto/tokenize.html)), so we can simply split them up by whitespace to get sequences of tokens.  To make your life a bit easier, we have removed sentences longer than 15 words.
#
# The next cell contains code that yields the sentences contained in a file as lists of strings:

# %%
ENGLISH = 0
SWEDISH = 1

def sentences(filename, idx):
    # Use idx=0 for English, idx=1 for Swedish
    with open(filename, "rt") as source:
        for line in source:
            yield line.rstrip().split("\t")[idx].split()

# Example usage
next(sentences("en-sv-train.txt", ENGLISH))
# Out:
# ['i', 'returned', 'to', 'japan', '.']

# %% [markdown]
# ## Part 1: Build the vocabularies

# %% [markdown]
# Before we can feed them into any model, we first need to convert the text strings to integers. For this purpose, we'll create a **vocabulary** of tokens that are known to the model, one vocabulary for each language. We need four **special tokens (or "pseudowords")**:
#
# 1. `<pad>` at index 0 for padding purposes
# 2. `<unk>` at index 1 to represent unknown words
# 3. `<bos>` at index 2 to mark the "beginning of sequence" in the decoder
# 4. `<eos>` at index 3 to mark the "end of sequence" in the decoder
#
# The remaining items in the vocabulary should be made up of the **most frequent words** in the training data for the respective language.

# %% [markdown]
# #### 🤔 Task 1: Write the function to build the vocabularies

# %%
from collections import Counter

def make_vocab(sentences,  max_size):
    """Return a list of the `max_size` most frequent tokens in `sentences`."""
    # TODO
    # 1. Count of how often each word occurs in the data
    # 2. Sort the words by their frequency, in descending order
    # 3. Make a list of the special tokens plus the most frequent words, up to a length of `max_size`.
    # 4. Return the list
    # Initialize a Counter object to count word frequencies
    word_counter = Counter()
    
    # Iterate through all sentences and update the word counter
    for words in sentences:
        word_counter.update(words)
    
    # Sort the words by frequency and get the most common words
    sorted_words = word_counter.most_common(max_size)
    
    # Add special tokens
    special_tokens = ["<pad>", "<unk>", "<bos>", "<eos>"]
    
    # Create the vocabulary list with special tokens and the most common words
    vocab_list = special_tokens + [word for word, _ in sorted_words[: max_size - len(special_tokens)]]
    
    # Print the vocabulary size
    print(f"Vocabulary size: {len(vocab_list)}")
    
    # Return the vocabulary list
    return vocab_list

# %% [markdown]
# With this function, we can construct vocabularies containing the 5,000 most frequent words as follows:

# %%
src_vocab = make_vocab(sentences('en-sv-train.txt', SWEDISH), 5000)
tgt_vocab = make_vocab(sentences('en-sv-train.txt', ENGLISH), 5000)
# Out:
# Vocabulary size: 5000
# Vocabulary size: 5000

# %%
print(src_vocab)
# Out:
# ['<pad>', '<unk>', '<bos>', '<eos>', '.', 'jag', 'är', '?', 'tom', 'det', 'du', 'inte', 'att', 'har', 'en', 'på', 'vi', 'här', 'var', 'han', 'mig', 'i', 'kan', 'den', 'om', 'för', 'vad', 'dig', 'med', 'till', 'ni', 'hur', 'ett', 'de', 'som', 'min', 'kommer', 'och', 'vill', ',', 'av', 'hon', 'måste', 'skulle', 'göra', 'så', 'där', 'mary', 'ha', 'tycker', 'gå', 'sig', 'mycket', 'vet', 'din', 'ska', 'ut', 'vara', 'nu', 'varför', 'behöver', '!', 'bara', 'gör', 'oss', 'er', 'hade', 'alla', 'ingen', 'gillar', 'vem', 'upp', 'kom', 'bra', 'ta', 'någon', 'när', 'aldrig', 'gjorde', 'går', 'tror', 'åt', 'honom', 'ser', 'mitt', 'än', 'ge', 'såg', 'lite', 'sa', 'borde', 'känner', 'blev', 'väldigt', 'får', 'detta', 'kunde', 'finns', 'toms', 'mina', 'älskar', 'alltid', 'sin', 'gick', 'hjälpa', 'allt', 'in', 'igen', 'fick', 'dag', 'få', 'många', 'ditt', 'verkligen', 'trodde', 'tillbaka', 'något', 'hans', 'tog', 'man', 'komma', 'någonting', 'efter', 'bil', 'eller', 'se', 'tre', 'fortfarande', 'två', 'ville', 'från', 'vilja', 'hatar', 'vilken', 'prata', 'köpte', 'hjälp', 'några', 'hem', 'tid', 'dem', 'bli', 'barn', 'mer', 'vid', 'rätt', 'franska', 'bor', 'äta', 'hela', 'visste', 'sitt', 'tala', 'över', 'äter', 'varit', 'låt', 'boston', 'år', 'pengar', 'inget', 'själv', 'skolan', 'hund', 'ligger', 'hoppas', 'gav', 'fel', 'henne', 'nästan', 'stanna', 'kunna', 'vänta', 'säga', 'sade', 'ingenting', 'hemma', 'sina', 'varje', 'håller', 'hus', 'åka', 'men', 'länge', 'säger', 'jobb', 'hämta', 'upptagen', 'tar', 'spela', 'dina', 'tänker', 'fråga', 'ofta', 'står', 'gång', 'idag', 'bilen', 'sett', 'ensam', 'tack', 'dörren', 'hennes', 'gjort', 'redan', 'verkar', 'stor', 'längre', 'gammal', 'också', 'berätta', 'faktiskt', 'önskar', 'vänner', 'kaffe', 'hittade', 'blir', 'trött', 'säker', 'namn', 'hände', 'roligt', 'ner', 'hand', 'bättre', 'vår', 'hit', 'köpa', 'svårt', 'mat', 'inga', 'boken', 'snäll', 'talar', 'vän', 'förstår', 'tv', 'sluta', 'problem', 'glad', 'veta', 'ont', 'bort', 'dit', 'tyckte', 'arg', 'spelar', 'träffa', 'mot', 'väg', 'hörde', 'nya', 'kanske', 'någonsin', 'sant', 'dagen', 'huset', 'far', 'morgon', 'kände', 'riktigt', 'precis', 'bror', 'tiden', 'under', 'titta', 'bok', 'håll', 'rum', 'dog', 'sedan', 'denna', 'lång', 'rädd', 'illa', 'engelska', 'hår', 'mamma', 'höra', 'slut', 'gott', 'misstag', 'läsa', 'just', 'försökte', 'skriva', 'tidigt', 'ännu', '”', 'tennis', 'skeppet', 'ny', 'hatt', 'öl', 'jobbet', 'nog', 'heter', 'kväll', 'hämtar', 'ganska', 'böcker', 'saker', 'nästa', 'liv', 'väntar', 'dagar', 'igår', 'sitter', 'utan', 'rummet', 'sover', 'senare', 'satt', 'pratar', 'marys', 'hunden', 'säg', 'lämna', 'vilka', 'vilket', 'föräldrar', 'började', 'snart', 'fru', 'lycklig', 'bad', '"', 'jobbar', 'stort', 'klockan', 'full', 'vatten', 'först', 'ens', 'saknar', 'fram', 'ned', 'lätt', 'hitta', 'ätit', 'sent', 'hålla', 'god', 'tittade', 'långt', 'kvar', 'problemet', 'andra', 'te', 'annat', 'dålig', 'klarar', 'köra', 'lärare', 'glömde', 'ur', 'idé', 'berättade', 'tillräckligt', 'låter', 'hör', 'frukost', 'tro', 'katten', 'borta', 'människor', 'ihåg', 'lita', 'emot', 'helst', 'tio', 'vacker', 'katt', 'vart', 'dö', 'snabbt', 'sen', 'helt', 'sätt', 'arbete', 'redo', 'minuter', 'simma', 'tvungen', 'nära', 'ung', 'sjuk', 'fort', 'höll', 'minns', 'åkte', 'era', 'sanningen', 'okej', 'glöm', 'son', 'imorgon', 'vägen', 'pappa', 'familj', 'lådan', 'be', 'dags', 'dricka', 'gånger', 'tag', 'blivit', 'svar', 'behövde', 'tåget', 'barnen', 'frågade', 'lunch', 'lära', 'hungrig', 'färdig', 'vin', 'dansa', 'båda', 'hända', 'följa', 'börjar', 'gamla', 'särskilt', 'fem', 'undrar', 'mår', 'bordet', 'skyldig', 'dricker', 'döda', 'fanns', 'skrev', 'lade', 'betala', 'knappt', 'rädda', 'ute', 'visade', 'ringa', 'bästa', 'träffade', 'dåligt', 'sov', 'enda', 'kör', 'ifrån', 'lika', 'bryr', 'händer', 'varandra', 'ringde', 'ögon', 'tur', 'beslut', 'arbetar', 'ön', 'behöva', 'låg', 'då', 'reda', 'rik', 'åker', 'alls', 'medan', 'öppna', 'inne', 'förstå', 'sova', 'innan',  ...

# %% [markdown]
# #### 🤞 Test your code
#
# To test your code, check that each vocabulary contains 5,000 words, and includes the pseudowords at the right positions:

# %%
def test1():
    assert len(src_vocab) == 5000
    assert len(tgt_vocab) == 5000
    assert src_vocab[:4] == ['<pad>', '<unk>', '<bos>', '<eos>']
    assert tgt_vocab[:4] == ['<pad>', '<unk>', '<bos>', '<eos>']
    print("All good!")

test1()
# Out:
# All good!

# %% [markdown]
# ### Wrap the vocabularies in StringLookup layers
#
# For mapping tokens to their vocabulary IDs, we can use Keras' `StringLookup` layer. The next cell constructs layers for both the source and target vocabulary.

# %%
string_lookup_args = dict(output_mode="int", mask_token="<pad>", oov_token="<unk>")
src_lookup = layers.StringLookup(vocabulary=src_vocab, **string_lookup_args)
tgt_lookup = layers.StringLookup(vocabulary=tgt_vocab, **string_lookup_args)

# %% [markdown]
# The next cell gives an example how these `StringLookup` layers can be used. Note that the layers already return *tensors*.

# %%
example = "i returned to japan yesterday .".split()
print(tgt_lookup(example))
# Out:
# tf.Tensor([   5 1005   11  530  188    4], shape=(6,), dtype=int64)

# %% [markdown]
# #### 🤔 Task 2: Sanity-check that these numbers are correct
#
# Check your understanding of what's happening in the `StringLookup` layer by writing two lines of code:
# 1. One that prints the token corresponding to the _second integer_ in the tensor above.
# 2. One that prints the integer corresponding to the _second word_ ("returned") in the example above.
#
# Use `tgt_vocab` directly for that, not the lookup layer!

# %%
## TODO: Your code here
tgt_vocab[1005]
tgt_vocab.index('returned')
# Out:
# 1005

# %% [markdown]
# ### Wrapping everything in data loaders

# %% [markdown]
# The next cell defines a function that wraps our dataset in TensorFlow's [`tf.data.Dataset`](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) API, which represents map-style datasets. The advantage of this is that it lets us use standard infrastructure related to the loading and automatic batching of data.

# %%
def append_eos(tensor):
    "Helper function that appends '<eos>' to a sequence."
    return tf.concat([tensor, tf.constant(["<eos>"], dtype=tf.string)], axis=0)

def load_translation_dataset(src_lookup, tgt_lookup, filename):
    # Build source dataset and convert with src_lookup
    src_dataset = tf.data.Dataset.from_tensor_slices(
        tf.ragged.constant(list(sentences(filename, SWEDISH)))
    )
    src_dataset = src_dataset.map(src_lookup)

    # Build target dataset, append <eos> and convert with tgt_lookup
    tgt_dataset = tf.data.Dataset.from_tensor_slices(
        tf.ragged.constant(list(sentences(filename, ENGLISH)))
    )
    tgt_dataset = tgt_dataset.map(append_eos).map(tgt_lookup)
    
    # Zip them together
    return tf.data.Dataset.zip((src_dataset, tgt_dataset))

# %% [markdown]
# We load the training data:

# %%
train_dataset = load_translation_dataset(src_lookup, tgt_lookup, "en-sv-train.txt")

# %% [markdown]
# The following function can be helpful for debugging. It extracts a single source–target pair of sentences from the specified *dataset* and converts it into batches of size&nbsp;1, which can be fed into the encoder–decoder model. This also illustrates how the `Dataset` API works:

# %%
def example(dataset, i):
    if i > 0:
        dataset = dataset.skip(i-1)
    return list(dataset.take(1).batch(1))[0]

# %%
x, y = example(train_dataset, 42)
print(x)
print(y)
# Out:
# tf.Tensor([[  6  10 245  15  20   7]], shape=(1, 6), dtype=int64)
# tf.Tensor([[ 29   9 477  55  28   8   3]], shape=(1, 7), dtype=int64)

# %% [markdown]
# ## Part 2: The encoder–decoder architecture

# %% [markdown]
# In this section, you will implement the encoder–decoder architecture, including the extension of that architecture by an attention mechanism. The implementation consists of four parts: the encoder, the attention mechanism, the decoder, and a class that wraps the complete architecture.

# %% [markdown]
# ### Part 2.1: Implement the encoder

# %% [markdown]
# The encoder is a component that takes an input tensor of vocabulary IDs, like the `x` tensor from the example above, and performs the following steps:
#
# 1. Look up **word embeddings** for each token in the sequence.
# 2. Process them with a **bi-directional recurrent neural network**. This works with any type of RNN, but we will use **GRU (gated recurrent unit) layers** throughout this laboration.
# 3. Feed the output through a linear layer. We also take the last hidden state of the forward GRU and the last hidden state of the backward GRU, concatenate them, and pass them through a linear layer. This produces a "summary" of the source sentence, which we will later feed into the decoder.

# %% [markdown]
# Let's implement the encoder by defining it as a **custom Keras layer.** For this, we have to define a class that subclasses from `keras.layers.Layer`, instantiate all required model weights and/or (sub)layers in the `__init__()` function, and uses them to perform the layer's computation in the `call()` function. Below is some skeleton code to get you started; you can also [read more about making custom layers in the Keras Docs](https://keras.io/guides/making_new_layers_and_models_via_subclassing/).

# %% [markdown]
# #### 🤔 Task 3: Implement the encoder by completing the skeleton code below

# %%
from tensorflow.keras.layers import Embedding, Bidirectional, GRU, Dense
class Encoder(layers.Layer):
    def __init__(self, num_words, embedding_dim=128, hidden_dim=256):
        super().__init__()
        # TODO: Add your code here that defines the required layers/weights
        self.embedding = Embedding(input_dim=num_words, output_dim=embedding_dim,
                                   mask_zero=True)
        self.rnn = Bidirectional(GRU(units = hidden_dim, return_sequences=True, 
                                     return_state=True))
        self.linear = Dense(hidden_dim)
        self.summary_dense = Dense(hidden_dim)

    def call(self, inputs):
        # TODO
        # 1. Look up the embeddings for the source words
        # 2. Apply a bi-directional GRU over the source sequences
        # 3. Apply a linear transformation to the GRU's output
        # 4. Concatenate forward + backward hidden states and apply a linear transformation on them too
        x = self.embedding(inputs)
        # Pass the embeddings through the bi-directional GRU
        mask = self.embedding.compute_mask(inputs)
        output, forward_h, backward_h = self.rnn(x, mask=mask)
        output = self.linear(output)
        summary = tf.concat([forward_h, backward_h], axis=-1)
        summary = self.summary_dense(summary)
        
        # Apply the mask to the output
        output._keras_mask = mask

        return output, summary

# %% [markdown]
# Your code must comply with the following specification:
#
# **__init__** (*num_words*, *embedding_dim* = 128, *hidden_dim* = 256)
#
# > Initialises the encoder. The encoder consists of an embedding layer that maps each of *num_words* words to an embedding vector of size *embedding_dim*, a bidirectional GRU that maps each embedding vector to a position-specific representation of size 2 × *hidden_dim*, and a final linear layer that projects these representations to new representations of size *hidden_dim*.
#
# **call** (*self*, *inputs*)
#
# > Takes a tensor *inputs* with source-language word ids and sends it through the encoder. The input tensor has shape (*batch_size*, *src_len*), where *src_len* is the length of the sentences in the batch. (We will make sure that all sentences in the same batch have the same length.) The method returns a pair of tensors (*output*, *hidden*), where *output* has shape (*batch_size*, *src_len*, *hidden_dim*), and *hidden* has shape (*batch_size*, *hidden_dim*).

# %% [markdown]
# #### 🤞 Test your code
#
# To test your code, instantiate an encoder, feed it the first source sentence in the training data, and check that the tensors returned by the encoder have the expected shapes.

# %%
def test21():
    src, tgt = example(train_dataset, 42)
    encoder = Encoder(src_lookup.vocabulary_size())
    output, hidden = encoder(src)
    print(output.shape)  # should be (batch_size, src_len, hidden_dim)
    print(hidden.shape)  # should be (batch_size, hidden_dim)

test21()
# Out:
# (1, 6, 256)
# (1, 256)

# %% [markdown]
# ### Part 2.2: Implement the attention mechanism

# %% [markdown]
# Your next task is to implement the attention mechanism. Recall that the purpose of this mechanism is to inform the decoder when generating the translation of the next word. For this, attention has access to the previous hidden state of the decoder, as well as the complete output of the encoder. It returns the attention-weighted sum of the encoder output, the so-called *context* vector. For later usage, we also return the attention weights.
#
# As mentioned in the lecture, attention can be implemented in various ways. One very simple implementation is *uniform attention*, which assigns equal weight to each position-specific representation in the output of the encoder, and completely ignores the hidden state of the decoder. This mechanism is implemented in the cell below:

# %%
class UniformAttention(layers.Layer):
    def __init__(self):
        super().__init__()
        self.supports_masking = True

    def call(self, decoder_hidden, encoder_output, mask=None):
        # Set all attention scores to the same constant value (0). After
        # the softmax, we will have uniform weights.
        scores = tf.zeros_like(encoder_output[:, :, -1])
        
        # Mask out the attention scores for the padding tokens. We set
        # them to -inf. After the softmax, we will have 0.
        if mask is not None:
            masked_value = -float('inf') * tf.ones_like(scores)
            scores = tf.where(mask, scores, masked_value)
        
        # Convert scores into weights
        alpha = tf.nn.softmax(scores, axis=1)
        
        # The context is the alpha-weighted sum of the encoder outputs.
        context = tf.linalg.matmul(tf.expand_dims(alpha, axis=1), encoder_output)
        context = tf.squeeze(context, axis=1)
        
        return alpha, context

# %% [markdown]
# One technical detail in this code is our use of *mask* to compute attention weights only for the ‘real’ tokens in the source sentences, but not for the padding tokens that we introduce to bring all sentences in a batch to the same length.
#
# Your task now is to implement the attention mechanism from the paper by [Bahdanau et al. (2015)](https://arxiv.org/abs/1409.0473). The relevant equation is in Section&nbsp;A.1.2:
#
# $$
# a(s_{i-1}, h_j) = v^{\top} \tanh(W s_{i-1} + U h_j)
# $$
#
# This equation specifies how to compute the attention score (a scalar) for the previous hidden state of the decoder, denoted by $s_{i-1}$, and the $j$-th position-specific representation in the output of the encoder, denoted by $h_j$. The equation refers to three parameters: a vector $v$ and $W$ and $U$. In PyTorch, these parameters can be represented in terms of (bias-free) linear layers that are trained along with the other parameters of the model.
#
# Here is the skeleton code for this problem. As you can see, your specific task is to initialise the required parameters and to compute the attention scores (*scores*); the rest of the code is the same as for the uniform attention.

# %% [markdown]
# #### 🤔 Task 4: Implement Bahdanau attention by completing the skeleton code below

# %%
class BahdanauAttention(layers.Layer):
    def __init__(self, hidden_dim=256):
        super().__init__()
        self.supports_masking = True
        # TODO: Add your code here that defines the required layers/weights
        self.w = layers.Dense(hidden_dim, use_bias=False)
        self.u = layers.Dense(hidden_dim, use_bias=False)
        self.v = layers.Dense(1, use_bias=False)

    def call(self, decoder_hidden, encoder_output, mask=None):
        # TODO: Replace the next line with your own code that computes the attention scores
        # Expand decoder_hidden to match encoder_output's shape
        decoder_hidden_expanded = tf.expand_dims(decoder_hidden, axis=1)

        scores = self.v(tf.nn.tanh(self.w(decoder_hidden_expanded) + self.u(encoder_output)))
        
        # Remove the last dimension to get shape [batch_size, src_len]
        scores = tf.squeeze(scores, axis=-1)
        # ... The rest of the code is as in UniformAttention — NO NEED TO MODIFY BELOW THIS LINE!

        # Mask out the attention scores for the padding tokens. We set
        # them to -inf. After the softmax, we will have 0.
        if mask is not None:
            masked_value = -float('inf') * tf.ones_like(scores)
            scores = tf.where(mask, scores, masked_value)
        
        # Convert scores into weights
        alpha = tf.nn.softmax(scores, axis=1)
        
        # The context is the alpha-weighted sum of the encoder outputs.
        context = tf.linalg.matmul(tf.expand_dims(alpha, axis=1), encoder_output)
        context = tf.squeeze(context, axis=1)
        
        return alpha, context

# %% [markdown]
# #### 🤞 Test your code
#
# To test your code, extend your test from Task 3: Feed the output of your encoder into your attention class. As the previous hidden state of the decoder, you can use the hidden state returned by the encoder. Later, you don't need to pass the mask explicitly (Keras will do this automatically), but for testing purposes, you can obtain the mask from a layer's output via `output._keras_mask`.
#
# Check that the context tensor and the attention weights returned by the attention class have the expected shapes.

# %%
def test22():
    src, tgt = example(train_dataset, 42)
    encoder = Encoder(src_lookup.vocabulary_size())
    output, hidden = encoder(src)
    attention = BahdanauAttention()
    alpha, context = attention(hidden, output, mask=output._keras_mask)
    print(alpha.shape)    # should be (batch_size, src_len)
    print(context.shape)  # should be (batch_size, hidden_dim)

test22()
# Out:
# (1, 6)
# (1, 256)

# %% [markdown]
# ### Part 2.3: Implement the decoder

# %% [markdown]
# Now you are ready to implement the decoder. Like the encoder, the decoder is based on a GRU; but this time we use a unidirectional network, as we generate the target sentences left-to-right.
#
# **⚠️ We expect that solving this problem will take you the longest time in this lab.**
#
# Because the decoder is an autoregressive model, we need to unroll the GRU "manually": At each position, we take the previous hidden state as well as the new input, and apply the GRU for one step. The initial hidden state comes from the encoder. The new input is the embedding of the previous word, concatenated with the context vector from the attention model. To produce the final output, we take the output of the GRU, concatenate the embedding vector and the context vector (residual connection), and feed the result into a linear layer. Here is a graphical representation:
#
# <img src="https://gitlab.liu.se/nlp/nlp-course/-/raw/master/labs/l3/decoder.svg" width="50%" alt="Decoder architecture"/>
#
# We need to implement this manual unrolling for two very similar tasks: When *training*, both the inputs to and the target outputs of the GRU come from the training data. When *decoding*, the outputs of the GRU are used to generate new target-side words, and these words become the inputs to the next step of the unrolling. **We have already implemented the `call` method that handles both these two different modes of usage — you don't need to modify this.**

# %% [markdown]
# #### 🤔 Task 5: Implement the `step` method that takes a single step with the GRU
#
# You will also need to add any necessary layers/weights that you use in the `__init__` function.

# %%
class Decoder(layers.Layer):
    def __init__(self, trg_lookup, attention, embedding_dim=128, hidden_dim=256, max_len=16):
        super().__init__()
        num_words = trg_lookup.vocabulary_size()
        self.embedding = layers.Embedding(num_words, embedding_dim, mask_zero=True)
        self.bos_index = trg_lookup(["<bos>"]).numpy()
        self.max_len = max_len
        # TODO: Add your code here that defines the required layers/weights
        self.attention = attention
        self.rnn_cell = layers.GRUCell(units = hidden_dim)
        self.linear = layers.Dense(units = num_words)

    def call(self, encoder_output, initial_state, targets=None, training=False, mask=None):
        # YOU WON'T NEED TO MODIFY ANYTHING IN THIS FUNCTION.

        if training:
            assert targets is not None

        # Initialise the hidden state from `initial_state`
        state = initial_state
        
        # Initialise the decoder input with the `<bos>` symbol
        next_input = self.bos_index * tf.ones_like(initial_state, dtype=tf.int64)
        next_input = next_input[:, 0]
        
        # Initialise the list of outputs and attention weights
        outputs = tf.TensorArray(
            tf.float32,
            size=0 if training else self.max_len,
            dynamic_size=training,
        )
        alphas = tf.TensorArray(
            tf.float32,
            size=0 if training else self.max_len,
            dynamic_size=training,
        )
        inputs = tf.TensorArray(
            tf.int64,
            size=0 if training else self.max_len,
            dynamic_size=training,
        )

        # In training mode, we iterate over the length of the target sentences,
        # otherwise we iterate until `self.max_len` is reached
        max_len = tf.shape(targets)[1] if training else self.max_len
        
        for i in range(max_len):
            # In training mode, we feed the correct (gold) predictions as the next input
            if training and i > 0:
                next_input = targets[:, i-1]
            
            # Get the embedding for the previous word
            prev_embed = self.embedding(next_input)
            
            # Take one step with the RNN
            step_output, state, alpha = self.step(encoder_output, state, prev_embed, mask=mask)
            
            # Update the list of generated words and attention weights
            outputs = outputs.write(i, step_output)
            alphas = alphas.write(i, alpha)
            inputs = inputs.write(i, next_input)

            # Set the prediction with highest probability as the input for the next timestep
            if not training:
                next_input = tf.math.argmax(step_output, axis=-1)

        # Lists of outputs and attention weights are [tgt_len, batch_size, *],
        # so we transpose them to have the batch dimension in first place again.
        outputs = tf.transpose(outputs.stack(), perm=[1,0,2])
        alphas = tf.transpose(alphas.stack(), perm=[1,0,2])
        inputs = tf.transpose(inputs.stack(), perm=[1,0])
        outputs._keras_mask = (inputs != 0)
        
        return outputs, alphas
    
    def step(self, encoder_output, hidden_state, prev_embed, mask=None):
        # TODO: Replace the next line with your own code; this should follow the illustration above.
        # 1. Get the attention weights and context vector
        alpha, context = self.attention(hidden_state, encoder_output, mask=mask)
        # 2. Concatenate the inputs for the GRU
        rnn_input = tf.concat([prev_embed, context], axis=-1)
        # 3. Take one step with the GRU cell
        rnn_output, states = self.rnn_cell(rnn_input, states=[hidden_state])
        hidden_state = states[0]  # Extract the tensor from the list

        # 4. Concatenate the respective tensors to produce the final output
        output = self.linear(rnn_output)
        
        return output, hidden_state, alpha

# %% [markdown]
# Your implementation should comply with the following specification:
#
# **step** (*self*, *encoder_output*, *hidden*, *prev_embed*, *mask*)
#
# > Performs a single step in the manual unrolling of the decoder GRU. This takes the output of the encoder (*encoder_output*), the previous hidden state of the decoder (*hidden*), the embedding vector of the previous word (*prev_embed*), and the source mask as described in Problem&nbsp;2.2 (*mask*), and computes the output as described above.
# >
# > The shape of *encoder_output* is (*batch_size*, *src_len*, *hidden_dim*); the shape of *hidden* is (*batch_size*, *hidden_dim*); the shape of *src_mask* is (*batch_size*, *src_len*); and the shape of *prev_embed* is (*batch_size*, *embedding_dim*).
# >
# > The method returns a triple of tensors (*output*, *hidden*, *alpha*) where *output* is the position-specific output of the GRU, of shape (*batch_size*, *num_words*); *hidden* is the new hidden state, of shape (*batch_size*, *hidden_dim*); and *alpha* are the attention weights that were used to compute the *output*, of shape (*batch_size*, *src_len*).
#
# #### 💡 Hints on the implementation
#
# **GRU vs. GRUCell.** In Keras, an RNN layer like `GRU` is used to process an entire sequence. A single *time-step* of a sequence is handled by a [`GRUCell`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GRUCell) instead. You can think of a `GRU` layer as functionally equivalent to a for-loop around a `GRUCell`. Since we want to perform the RNN steps individually for this model, you should use a [`GRUCell`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/GRUCell) instead of a `GRU` layer here.

# %% [markdown]
# #### 🤞 Test your code
#
# To test your code, extend your test from the previous problems, and simulate a complete forward pass of the encoder–decoder architecture on the example sentence. Check the shapes of the resulting tensors.

# %%
def test23():
    src, tgt = list(train_dataset.take(4).padded_batch(4))[0]
    encoder = Encoder(src_lookup.vocabulary_size())
    encoder_output, hidden = encoder(src)
    attention = BahdanauAttention()
    decoder = Decoder(tgt_lookup, attention)
    decoded, alphas = decoder(encoder_output, hidden)
    print(decoded.shape)  # should be (batch_size, max_len, vocabulary_size)
    print(alphas.shape)   # should be (batch_size, max_len, src_len)
    decoded, _ = decoder(encoder_output, hidden, targets=tgt, training=True)
    print(decoded.shape)  # should be (batch_size, tgt_len, vocabulary_size)

test23()
# Out:
# (4, 16, 5000)
# (4, 16, 5)
# (4, 8, 5000)

# %% [markdown]
# ### Encoder–Decoder wrapper class

# %% [markdown]
# The last part of the implementation is a class that wraps the encoder and the decoder as a single model.  We also implement a custom `train_step` function so that the gold targets will get passed to the decoder during training, and a custom `test_step` function to make sure the decoded sequences and the gold sequences are padded to the same length before computing losses and evaluation metrics.

# %%
class EncoderDecoder(keras.Model):
    def __init__(self, src_lookup, tgt_lookup, embedding_dim=128, hidden_dim=256, max_len=16, **kwargs):
        super().__init__(**kwargs)
        self.encoder = Encoder(
            src_lookup.vocabulary_size(),
            embedding_dim=embedding_dim,
            hidden_dim=hidden_dim
        )
        self.decoder = Decoder(
            tgt_lookup,
            BahdanauAttention(hidden_dim=hidden_dim),
            embedding_dim=embedding_dim,
            hidden_dim=hidden_dim,
            max_len=max_len,
        )
    
    def call(self, inputs, training=False, targets=None):
        x_out, x_hidden = self.encoder(inputs, training=training)
        outputs, alphas = self.decoder(x_out, x_hidden, training=training, targets=targets)
        if training:
            return outputs
        else:
            return outputs, alphas
    
    # Following <https://keras.io/guides/customizing_what_happens_in_fit/>
    def train_step(self, data):
        x, y = data
        
        with tf.GradientTape() as tape:
            # Here we supply "targets" so that the decoder has access to it
            y_pred = self(x, training=True, targets=y)
            loss = self.compiled_loss(y, y_pred, regularization_losses=self.losses)
        
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.compiled_metrics.update_state(y, y_pred)
        return {m.name: m.result() for m in self.metrics}
    
    def test_step(self, data):
        x, y = data
        y_pred, _alphas = self(x, training=False)

        # Pad sequences to the same number of time-steps
        max_len = tf.math.maximum(tf.shape(y)[1], tf.shape(y_pred)[1])
        y_pad = [[0, 0], [0, max_len - tf.shape(y)[1]]]
        y = tf.pad(y, y_pad)
        y_pred_pad = [[0, 0], [0, max_len - tf.shape(y_pred)[1]], [0, 0]]
        y_pred = tf.pad(y_pred, y_pred_pad)
            
        self.compute_loss(x, y, y_pred, None)
        return self.compute_metrics(x, y, y_pred, None)

# %% [markdown]
# #### 🤞 Test your code
#
# As a final test, instantiate an encoder–decoder model and use it to decode the example sentence. Check the shapes of the resulting tensors.

# %%
def test24():
    src, tgt = example(train_dataset, 42)
    encoder_decoder = EncoderDecoder(src_lookup, tgt_lookup)
    outputs, alphas = encoder_decoder(src)
    print(outputs.shape)  # should be (batch_size, max_len, vocabulary_size)
    print(alphas.shape)   # should be (batch_size, max_len, src_len)

test24()
# Out:
# (1, 16, 5000)
# (1, 16, 6)

# %% [markdown]
# ## Part 3: Train a translator

# %% [markdown]
# We now have all the pieces to build and train a complete translation system.

# %% [markdown]
# ### Translator class
#
# We first define a class `Translator` that initialises an encoder–decoder model and uses it to translate sentences.

# %%
class Translator:
    def __init__(self, src_lookup, tgt_lookup, batch_size=32, **kwargs):
        self.src_lookup = src_lookup
        self.tgt_lookup = tgt_lookup
        self.model = EncoderDecoder(src_lookup, tgt_lookup, **kwargs)
        self.tgt_vocab = tgt_lookup.get_vocabulary()
        self.eos_index = self.tgt_vocab.index("<eos>")
        self.batch_size = batch_size

    def compile(self, *args, **kwargs):
        return self.model.compile(*args, **kwargs)

    def fit(self, *args, **kwargs):
        return self.model.fit(*args, **kwargs)

    def translate(self, sentences, return_alphas=False):
        """This function takes sentences and returns their translation as a string.
        
        `sentences` can be either:
          - A tf.data.Dataset object
          - A list of strings
        """
        if isinstance(sentences, tf.data.Dataset):
            inputs = sentences
        elif isinstance(sentences, (list, tuple)):
            inputs = (
                tf.data.Dataset.from_tensor_slices(
                    tf.ragged.constant([x.split() for x in sentences])
                )
                .map(self.src_lookup)
                .padded_batch(min(self.batch_size, len(sentences)))
            )
        else:
            raise ValueError(f"'sentences' should be either a tf.Dataset or a list of strings; got: {type(sentences)}")

        outputs, alphas = self.model.predict(inputs, verbose=0)
        outputs = tf.math.argmax(outputs, axis=-1).numpy().tolist()
        try:
            alphas = alphas.numpy().tolist()
        except AttributeError:
            alphas = alphas.tolist()
        generated = []

        for y_pred, alpha in zip(outputs, alphas):
            try:
                eos_idx = y_pred.index(self.eos_index)
                del y_pred[eos_idx:]
                del alpha[eos_idx:]
            except ValueError:
                pass
            tokens = [self.tgt_vocab[idx] for idx in y_pred if idx > 0]
            tokens = " ".join(tokens)
            if return_alphas:
                generated.append((tokens, alpha))
            else:
                generated.append(tokens)

        return generated
        
    def translate_with_attention(self, sentences):
        return self.translate(sentences, return_alphas=True)

# %% [markdown]
# The code below shows how this class is supposed to be used (its output will be nonsensical right now, of course, since the model hasn't been trained yet):

# %%
translator = Translator(src_lookup, tgt_lookup)
# Alternative "mini" version of the model for testing:
#translator = Translator(src_lookup, tgt_lookup, embedding_dim=32, hidden_dim=64, batch_size=16, max_len=8)
translator.translate(['stäng av vattnet .', 'jag älskar friterade bananer .'])
# Out:
# ['nearly pitch christians colonels courage player volume sinking nets line line duck organization stretch melt mean',
#  'refrigerator lies diploma shoulders risks risks shoulders risks shoulders risks shoulders risks risks mad musician deeply']

# %% [markdown]
# ### Evaluation function
#
# As mentioned in the lecture, machine translation systems are typically evaluated using the **BLEU metric**. Here we use the implementation of this metric from the `sacrebleu` library.

# %%
from sacrebleu.metrics import BLEU
bleu_params = dict(effective_order=True, tokenize="none", force=True, smooth_method="floor", smooth_value=0.01)
bleu = BLEU(**bleu_params)

# %% [markdown]
# If the test sentence is exactly identical to the reference sentence, the score will be 100 (plus/minus potential floating point rounding errors):

# %%
bleu.sentence_score("the house is blue .", ["the house is blue ."]).score
# Out:
# 100.00000000000004

# %% [markdown]
# If we change some words, the score will go down, though never below zero:

# %%
bleu.sentence_score("the house was red .", ["the house is blue ."]).score
# Out:
# 3.9763536438352522

# %% [markdown]
# Here is a helper function that takes a trained `Translator` model as well as a `Dataset`, runs all sentences through the translator, and computes the BLEU score for the entire dataset:

# %%
def compute_bleu(translator, dataset):
    hyp = translator.translate(dataset)
    ref = [
        " ".join(translator.tgt_vocab[idx] for idx in s if idx not in (0, translator.eos_index))
        for s in dataset.unbatch().map(lambda _, x: x).as_numpy_iterator()
    ]
    return bleu.corpus_score(hyp, [ref]).score

# %% [markdown]
# We want to report the BLEU score on the **validation data**, so let's load this as well:

# %%
valid_dataset = load_translation_dataset(src_lookup, tgt_lookup, "en-sv-valid.txt")

# %% [markdown]
# ### Batching
#
# So far we only tested our code on "batches" with a single sentence. In order to use larger batches, we need to make sure that all of the sentences in a batch have the same length. We achieve this by _padding_ the shorter sentences to the length of the longest one. Luckily, the `tf.Dataset` class has a function [`padded_batch`](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#padded_batch) that will do this for us. If we provide a `Dataset` for training, Keras won't shuffle the data automatically, so we also have to [`shuffle`](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#shuffle) the dataset explicitly. (For validation, shuffling doesn't matter.)

# %%
train_batched = train_dataset.shuffle(512).padded_batch(64)
valid_batched = valid_dataset.padded_batch(64)

# %% [markdown]
# ### Training
#
# Training works as for any other Keras model: we first need to `compile` the model with the optimizer, loss function, and validation metrics that we want to use.

# %%
translator.compile(
    optimizer=keras.optimizers.Adam(learning_rate=2e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True)
)

# %% [markdown]
# Now it is time to train the system. During training, these diagnostics will be updated periodically: the running average of the training loss; after a full epoch, the loss and the BLEU score on the validation data will be computed and printed.
#
# Let's also define a callback that additionally prints the translation of a sample sentence, *jag saknar min familj* (which should translate into *i miss my family*), every 50 batches:

# %%
my_callbacks = [
    keras.callbacks.LambdaCallback(
        on_train_batch_end=lambda b, _: tf.print(" - jag saknar min familj . ->", translator.translate(['jag saknar min familj .'])[0]) if b > 0 and b % 50 == 0 else None,
        on_epoch_end=lambda _, l: l.__setitem__("val_bleu", compute_bleu(translator, valid_batched))
    )
]

# %% [markdown]
# #### 🤔 Task 6: Run the model training
#
# Run the following code cells that train the model and evaluate it on the validation data.
#
# Training the translator takes quite a bit of compute power and time. The default number of epochs is 2; however, you may want to try training for longer, or interrupt the training prematurely and use a partially trained model in case you run out of time.
#
# **⚠️ Your submitted notebook must contain output demonstrating at least 20 BLEU points on the validation data.**

# %%
# %%time
try:
    translator.fit(train_batched, epochs=50, validation_data=valid_batched, callbacks=my_callbacks)
except KeyboardInterrupt:
    pass
# Out:
# Epoch 1/50
#  50/322 [===>..........................] - ETA: 18s - loss: 6.0949 - jag saknar min familj . -> i
# 100/322 [========>.....................] - ETA: 18s - loss: 5.3709 - jag saknar min familj . -> i ' ' ' ' ' .
# 150/322 [============>.................] - ETA: 13s - loss: 4.9281 - jag saknar min familj . -> i ' ' ' ' ' ' ' ' ' ' ' ' ' ' '
# 200/322 [=================>............] - ETA: 9s - loss: 4.6361 - jag saknar min familj . -> i ' t the a .
# 250/322 [======================>.......] - ETA: 5s - loss: 4.4138 - jag saknar min familj . -> i ' s <unk> .
# 300/322 [==========================>...] - ETA: 1s - loss: 4.2248 - jag saknar min familj . -> i ' m not a <unk> .
# 322/322 [==============================] - 35s 97ms/step - loss: 4.1539 - val_loss: 4.0666 - val_bleu: 2.2904
# Epoch 2/50
#  50/322 [===>..........................] - ETA: 19s - loss: 3.1851 - jag saknar min familj . -> i ' m not a book .
# 100/322 [========>.....................] - ETA: 16s - loss: 3.1427 - jag saknar min familj . -> i ' m not to go to be .
# 150/322 [============>.................] - ETA: 12s - loss: 3.1000 - jag saknar min familj . -> i ' m not a lot of the room .
# 200/322 [=================>............] - ETA: 8s - loss: 3.0655 - jag saknar min familj . -> i ' m not a lot of the day .
# 250/322 [======================>.......] - ETA: 5s - loss: 3.0245 - jag saknar min familj . -> i ' m not a good .
# 300/322 [==========================>...] - ETA: 1s - loss: 2.9793 - jag saknar min familj . -> i ' m not a lot of <unk> .
# 322/322 [==============================] - 26s 81ms/step - loss: 2.9608 - val_loss: 4.9346 - val_bleu: 2.7867
# Epoch 3/50
#  50/322 [===>..........................] - ETA: 19s - loss: 2.7475 - jag saknar min familj . -> i ' m not a little time .
# 100/322 [========>.....................] - ETA: 15s - loss: 2.7051 - jag saknar min familj . -> i ' m not going to go to you .
# 150/322 [============>.................] - ETA: 12s - loss: 2.6684 - jag saknar min familj . -> i ' m not a lot of the dictionary .
# 200/322 [=================>............] - ETA: 8s - loss: 2.6337 - jag saknar min familj . -> i ' m going to go to you .
# 250/322 [======================>.......] - ETA: 5s - loss: 2.5967 - jag saknar min familj . -> i ' m not going to go to you .
# 300/322 [==========================>...] - ETA: 1s - loss: 2.5582 - jag saknar min familj . -> i ' m going to the gym .
# 322/322 [==============================] - 26s 81ms/step - loss: 2.5417 - val_loss: 5.0217 - val_bleu: 6.1143
# Epoch 4/50
#  50/322 [===>..........................] - ETA: 19s - loss: 2.3619 - jag saknar min familj . -> i ' m going to go to you .
# 100/322 [========>.....................] - ETA: 15s - loss: 2.3294 - jag saknar min familj . -> i ' ll get the coat .
# 150/322 [============>.................] - ETA: 12s - loss: 2.2932 - jag saknar min familj . -> i ' ll get a coat .
# 200/322 [=================>............] - ETA: 8s - loss: 2.2621 - jag saknar min familj . -> i ' ll get my coat .
# 250/322 [======================>.......] - ETA: 5s - loss: 2.2298 - jag saknar min familj . -> i ' ll be ready .
# 300/322 [==========================>...] - ETA: 1s - loss: 2.1996 - jag saknar min familj . -> i ' m going to a gym .
# 322/322 [==============================] - 26s 81ms/step - loss: 2.1867 - val_loss: 5.0853 - val_bleu: 8.3734
# Epoch 5/50
#  50/322 [===>..........................] - ETA: 20s - loss: 2.0439 - jag saknar min familj . -> i ' m going to get my coat .
# 100/322 [========>.....................] - ETA: 15s - loss: 2.0196 - jag saknar min familj . -> i ' ll get my coat .
# 150/322 [============>.................] - ETA: 12s - loss: 1.9847 - jag saknar min familj . -> i ' m going to go to you .
# 200/322 [=================>............] - ETA: 8s - loss: 1.9550 - jag saknar min familj . -> i ' ll get my coat .
# 250/322 [======================>.......] - ETA: 5s - loss: 1.9307 - jag saknar min familj . -> i ' ll get up now .
# 300/322 [==========================>...] - ETA: 1s - loss: 1.9076 - jag saknar min familj . -> i ' ll get my coat .
# 322/322 [==============================] - 26s 81ms/step - loss: 1.8974 - val_loss: 5.1317 - val_bleu: 10.8040
# Epoch 6/50
#  50/322 [===>..........................] - ETA: 19s - loss: 1.7808 - jag saknar min familj . -> i ' ll get my coat .
# 100/322 [========>.....................] - ETA: 15s - loss: 1.7491 - jag saknar min familj . -> i ' ll get my coat .
# 150/322 [============>.................] - ETA: 12s - loss: 1.7228 - jag saknar min familj . -> i ' ll go to you .
# 200/322 [=================>............] - ETA: 8s - loss: 1.6967 - jag saknar min familj . -> i ' ll be able to help you .
# 250/322 [======================>.......] - ETA: 5s - loss: 1.6762 - jag saknar min familj . -> i ' ll get out of my car .
# 300/322 [==========================>...] - ETA: 1s - loss: 1.6602 - jag saknar min familj . -> i ' ll go to you .
# 322/322 [==============================] - 26s 81ms/step - loss: 1.6518 - val_loss: 5.3061 - val_bleu: 11.9189
# Epoch 7/50
#  50/322 [===>..........................] - ETA: 19s - loss: 1.5379 - jag saknar min familj . -> i ' ll get my coat .
# 100/322 [========>.....................] - ETA: 15s - loss: 1.5201 - jag saknar min familj . -> i ' ll get my coat .
# 150/322 [============>.................] - ETA: 12s - loss: 1.4957 - jag saknar min familj . -> i ' ll go to the beach .
# 200/322 [=================>............] - ETA: 8s - loss: 1.4755 - jag saknar min familj . -> i ' m going to working down .
# 250/322 [======================>.......] - ETA: 5s - loss: 1.4582 - jag saknar min familj . -> i ' ll get up now .
# 300/322 [==========================>...] - ETA: 1s - loss: 1.4444 - jag saknar min familj . -> i ' m going to my grandmother ' s .
# 322/322 [==============================] - 26s 81ms/step - loss: 1.4382 - val_loss: 5.5166 - val_bleu: 14.0924
# Epoch 8/50
#  50/322 [===>..........................] - ETA: 19s - loss: 1.3357 - jag saknar min familj . -> i ' ll get my coat .
# 100/322 [========>.....................] - ETA: 15s - loss: 1.3196 - jag saknar min familj . -> i ' ll get my coat .
# 150/322 [============>.................] - ETA: 12s - loss: 1.2964 - jag saknar min familj . -> i ' ll go to the beach .
# 200/322 [=================>............] - ETA: 8s - loss: 1.2839 - jag saknar min familj . -> i ' ll be fine .
# 250/322 [======================>.......] - ETA: 5s - loss: 1.2699 - jag saknar min familj . -> i ' ll drive you there .
# 300/322 [==========================>...] - ETA: 1s - loss: 1.2616 - jag saknar min familj . -> i ' ll get my coat .
# 322/322 [==============================] - 26s 81ms/step - loss: 1.2557 - val_loss: 5.6457 - val_bleu: 15.1732
# Epoch 9/50
#  50/322 [===>..........................] - ETA: 19s - loss: 1.1717 - jag saknar min familj . -> i ' m going to cut down .
# 100/322 [========>.....................] - ETA: 15s - loss: 1.1535 - jag saknar min familj . -> i ' ll get my coat .
# 150/322 [============>.................] - ETA: 12s - loss: 1.1343 - jag saknar min familj . -> i ' ll miss my seat .
# 200/322 [=================>............] - ETA: 8s - loss: 1.1216 - jag saknar min familj . -> i ' ll be fine .
# 250/322 [======================>.......] - ETA: 5s - loss: 1.1104 - jag saknar min familj . -> i ' ll handle my bags .
# 300/322 [==========================>...] - ETA: 1s - loss: 1.1046 - jag saknar min familj . -> i ' ll shoot .
# 322/322 [==============================] - 26s 80ms/step - loss: 1.1003 - val_loss: 5.7767 - val_bleu: 15.9854
# Epoch 10/50
#  50/322 [===>..........................] - ETA: 20s - loss: 1.0251 - jag saknar min familj . -> i ' m going to study abroad .
# 100/322 [========>.....................] - ETA: 16s - loss: 1.0183 - jag saknar min familj . -> i ' ll take the train .
# 150/322 [============>.................] - ETA: 13s - loss: 1.0026 - jag saknar min familj . -> i ' ll drive you there .
# 200/322 [=================>............] - ETA: 9s - loss: 0.9905 - jag saknar min familj . -> i ' ll handle my bags .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.9807 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.9774 - jag saknar min familj . -> i ' ll get my coat .
# 322/322 [==============================] - 27s 84ms/step - loss: 0.9737 - val_loss: 5.8862 - val_bleu: 17.0870
# Epoch 11/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.9037 - jag saknar min familj . -> i ' ll be ready for .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.8959 - jag saknar min familj . -> i ' ll take the check .
# 150/322 [============>.................] - ETA: 12s - loss: 0.8832 - jag saknar min familj . -> i ' ll be ready for the next train .
# 200/322 [=================>............] - ETA: 8s - loss: 0.8752 - jag saknar min familj . -> i ' ll handle my bags .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.8687 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.8651 - jag saknar min familj . -> i ' ll shoot .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.8623 - val_loss: 6.0681 - val_bleu: 17.9638
# Epoch 12/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.8072 - jag saknar min familj . -> i ' ll handle my seat .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.7968 - jag saknar min familj . -> i ' ll get off .
# 150/322 [============>.................] - ETA: 12s - loss: 0.7875 - jag saknar min familj . -> i ' ll be back in .
# 200/322 [=================>............] - ETA: 8s - loss: 0.7799 - jag saknar min familj . -> i ' ll handle my bags .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.7754 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.7733 - jag saknar min familj . -> i ' ll help .
# 322/322 [==============================] - 26s 82ms/step - loss: 0.7713 - val_loss: 6.2481 - val_bleu: 19.1333
# Epoch 13/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.7240 - jag saknar min familj . -> i ' ll handle my seat .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.7141 - jag saknar min familj . -> i greatly appreciate your advice .
# 150/322 [============>.................] - ETA: 12s - loss: 0.7069 - jag saknar min familj . -> i ' ll be fine .
# 200/322 [=================>............] - ETA: 8s - loss: 0.7003 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.6962 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.6936 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.6923 - val_loss: 6.3238 - val_bleu: 19.8287
# Epoch 14/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.6475 - jag saknar min familj . -> i ' ll check it .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.6429 - jag saknar min familj . -> i greatly appreciate your advice .
# 150/322 [============>.................] - ETA: 12s - loss: 0.6394 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.6324 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.6286 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.6300 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.6278 - val_loss: 6.6255 - val_bleu: 20.1452
# Epoch 15/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.5881 - jag saknar min familj . -> i ' m going to throw one .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.5849 - jag saknar min familj . -> i ' m going to throw a ball back .
# 150/322 [============>.................] - ETA: 12s - loss: 0.5821 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.5766 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.5745 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.5733 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.5726 - val_loss: 6.7071 - val_bleu: 20.8677
# Epoch 16/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.5374 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.5288 - jag saknar min familj . -> i ' ll take the incident .
# 150/322 [============>.................] - ETA: 12s - loss: 0.5265 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.5235 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.5228 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.5229 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.5218 - val_loss: 6.8167 - val_bleu: 20.9901
# Epoch 17/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.4891 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.4840 - jag saknar min familj . -> i ' m going to cut down myself .
# 150/322 [============>.................] - ETA: 12s - loss: 0.4822 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.4789 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.4791 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.4801 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.4792 - val_loss: 7.0191 - val_bleu: 20.8423
# Epoch 18/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.4506 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.4465 - jag saknar min familj . -> i ' m going to throw a ball away .
# 150/322 [============>.................] - ETA: 12s - loss: 0.4458 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.4447 - jag saknar min familj . -> i miss you , too .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.4438 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.4446 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.4436 - val_loss: 7.2360 - val_bleu: 20.8619
# Epoch 19/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.4161 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.4119 - jag saknar min familj . -> i ' ll take the incident .
# 150/322 [============>.................] - ETA: 12s - loss: 0.4129 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.4107 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.4107 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.4113 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.4108 - val_loss: 7.3613 - val_bleu: 21.5677
# Epoch 20/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.3898 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.3872 - jag saknar min familj . -> i ' ll take the train .
# 150/322 [============>.................] - ETA: 12s - loss: 0.3849 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.3841 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.3850 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.3862 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.3852 - val_loss: 7.4994 - val_bleu: 21.8033
# Epoch 21/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.3618 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.3587 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.3598 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.3602 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.3625 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.3625 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.3620 - val_loss: 7.4742 - val_bleu: 21.9799
# Epoch 22/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.3412 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.3363 - jag saknar min familj . -> i ' m willing to share .
# 150/322 [============>.................] - ETA: 12s - loss: 0.3377 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.3373 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.3387 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.3403 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.3399 - val_loss: 7.8989 - val_bleu: 21.5798
# Epoch 23/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.3242 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.3208 - jag saknar min familj . -> i ' m willing to share .
# 150/322 [============>.................] - ETA: 12s - loss: 0.3221 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.3203 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.3215 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.3225 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.3219 - val_loss: 7.4628 - val_bleu: 23.2130
# Epoch 24/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.3048 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.3033 - jag saknar min familj . -> i ' m willing to share .
# 150/322 [============>.................] - ETA: 12s - loss: 0.3041 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.3024 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.3038 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.3047 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.3045 - val_loss: 7.8504 - val_bleu: 23.6886
# Epoch 25/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2950 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2900 - jag saknar min familj . -> i greatly appreciate your advice .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2927 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2909 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2911 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2916 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2912 - val_loss: 7.6412 - val_bleu: 23.1322
# Epoch 26/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2755 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2730 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2742 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2730 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2750 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2764 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.2760 - val_loss: 8.0081 - val_bleu: 23.3767
# Epoch 27/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2608 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2571 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2605 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2603 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2615 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2630 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2628 - val_loss: 7.9060 - val_bleu: 24.0724
# Epoch 28/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2524 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2489 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2498 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2491 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2512 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2518 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2515 - val_loss: 7.9603 - val_bleu: 24.1527
# Epoch 29/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2395 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2361 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2370 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2370 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2387 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2404 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2400 - val_loss: 8.0225 - val_bleu: 23.7773
# Epoch 30/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2265 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2241 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2257 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2265 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2275 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2292 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2294 - val_loss: 8.1828 - val_bleu: 24.3090
# Epoch 31/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2200 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2182 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2204 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2195 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2213 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2225 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2230 - val_loss: 7.9871 - val_bleu: 24.9184
# Epoch 32/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2182 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2160 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2175 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2178 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2196 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2216 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2218 - val_loss: 8.2186 - val_bleu: 24.8200
# Epoch 33/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2150 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2141 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2156 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2148 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2154 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2165 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.2164 - val_loss: 8.3814 - val_bleu: 25.1264
# Epoch 34/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.2153 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.2107 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.2102 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.2094 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2105 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2121 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.2119 - val_loss: 8.3864 - val_bleu: 24.3275
# Epoch 35/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.1974 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1949 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1975 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1980 - jag saknar min familj . -> i miss your family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.2002 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.2027 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 81ms/step - loss: 0.2029 - val_loss: 8.2811 - val_bleu: 24.9357
# Epoch 36/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1952 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.1911 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1923 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1922 - jag saknar min familj . -> i miss the family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1927 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1939 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 80ms/step - loss: 0.1935 - val_loss: 8.5035 - val_bleu: 24.4732
# Epoch 37/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1852 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1794 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1823 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 9s - loss: 0.1824 - jag saknar min familj . -> i miss you right .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1841 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1853 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 28s 87ms/step - loss: 0.1860 - val_loss: 8.8504 - val_bleu: 25.1277
# Epoch 38/50
#  50/322 [===>..........................] - ETA: 22s - loss: 0.1826 - jag saknar min familj . -> i miss anything right .
# 100/322 [========>.....................] - ETA: 17s - loss: 0.1783 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 13s - loss: 0.1790 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 9s - loss: 0.1783 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1793 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1796 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 28s 88ms/step - loss: 0.1801 - val_loss: 8.9057 - val_bleu: 25.0243
# Epoch 39/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.1690 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1679 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1692 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 9s - loss: 0.1700 - jag saknar min familj . -> i miss my school .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1710 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1720 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 84ms/step - loss: 0.1721 - val_loss: 9.0923 - val_bleu: 25.0608
# Epoch 40/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1698 - jag saknar min familj . -> i miss my jokes .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1701 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1736 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1757 - jag saknar min familj . -> i miss your family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1781 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1797 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 83ms/step - loss: 0.1799 - val_loss: 8.2633 - val_bleu: 24.9478
# Epoch 41/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1766 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1709 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1712 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1714 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1735 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1751 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 84ms/step - loss: 0.1753 - val_loss: 9.1972 - val_bleu: 25.0836
# Epoch 42/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.1681 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1636 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1662 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1663 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1674 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1682 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 82ms/step - loss: 0.1682 - val_loss: 9.6005 - val_bleu: 24.8695
# Epoch 43/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1612 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.1553 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1580 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1578 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1598 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1615 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 26s 82ms/step - loss: 0.1621 - val_loss: 9.5048 - val_bleu: 25.1530
# Epoch 44/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.1609 - jag saknar min familj . -> i miss my jokes .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1569 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1582 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1579 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1600 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1620 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 84ms/step - loss: 0.1627 - val_loss: 9.3643 - val_bleu: 25.7220
# Epoch 45/50
#  50/322 [===>..........................] - ETA: 20s - loss: 0.1595 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1558 - jag saknar min familj . -> i miss it .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1586 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 9s - loss: 0.1571 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1587 - jag saknar min familj . -> i miss my family .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1596 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 28s 87ms/step - loss: 0.1603 - val_loss: 9.5391 - val_bleu: 26.0434
# Epoch 46/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1525 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1528 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1566 - jag saknar min familj . -> i miss you right .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1565 - jag saknar min familj . -> i miss you that .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1573 - jag saknar min familj . -> i miss you , that we are .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1588 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 83ms/step - loss: 0.1584 - val_loss: 9.5653 - val_bleu: 25.7349
# Epoch 47/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1489 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 15s - loss: 0.1456 - jag saknar min familj . -> i miss the elevator .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1473 - jag saknar min familj . -> i miss you right .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1489 - jag saknar min familj . -> i miss you , that we are .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1502 - jag saknar min familj . -> i miss you that we .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1514 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 83ms/step - loss: 0.1516 - val_loss: 9.2701 - val_bleu: 25.7894
# Epoch 48/50
#  50/322 [===>..........................] - ETA: 21s - loss: 0.1427 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1382 - jag saknar min familj . -> i miss my family .
# 150/322 [============>.................] - ETA: 13s - loss: 0.1407 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 9s - loss: 0.1413 - jag saknar min familj . -> i miss you that .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1431 - jag saknar min familj . -> i miss you , that we are .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1441 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 28s 87ms/step - loss: 0.1444 - val_loss: 9.9404 - val_bleu: 25.5393
# Epoch 49/50
#  50/322 [===>..........................] - ETA: 21s - loss: 0.1350 - jag saknar min familj . -> i miss my family .
# 100/322 [========>.....................] - ETA: 17s - loss: 0.1325 - jag saknar min familj . -> i miss how to do that .
# 150/322 [============>.................] - ETA: 13s - loss: 0.1355 - jag saknar min familj . -> i miss how to play .
# 200/322 [=================>............] - ETA: 9s - loss: 0.1360 - jag saknar min familj . -> i miss you , too .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1380 - jag saknar min familj . -> i miss you , that we are .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1381 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 28s 86ms/step - loss: 0.1384 - val_loss: 9.6668 - val_bleu: 25.2695
# Epoch 50/50
#  50/322 [===>..........................] - ETA: 19s - loss: 0.1356 - jag saknar min familj . -> i miss all busy .
# 100/322 [========>.....................] - ETA: 16s - loss: 0.1323 - jag saknar min familj . -> i miss how we ' re doing .
# 150/322 [============>.................] - ETA: 12s - loss: 0.1359 - jag saknar min familj . -> i miss my family .
# 200/322 [=================>............] - ETA: 8s - loss: 0.1361 - jag saknar min familj . -> i miss my family .
# 250/322 [======================>.......] - ETA: 5s - loss: 0.1383 - jag saknar min familj . -> i miss you , too .
# 300/322 [==========================>...] - ETA: 1s - loss: 0.1400 - jag saknar min familj . -> i miss my family .
# 322/322 [==============================] - 27s 83ms/step - loss: 0.1404 - val_loss: 9.5522 - val_bleu: 25.5986
# CPU times: total: 4h 4min 7s
# Wall time: 22min 6s

# %%
compute_bleu(translator, valid_batched)
# Out:
# 25.59864596236715

# %% [markdown]
# #### ℹ️ Some notes on the translations
#
# If you try out sentences to see their translation (like in the code cell below), you might find some possibly surprising results, such as:
#
# - **Translations that are seemingly nonsensical or have nothing to do with the input.** This might be because the model is undertrained; you could try training for more epochs to see if the translations improve. It's also possible that you tried words or phrases that were just not well-represented in the training data.
# - **Translations that have a lot of `<unk>`s.** This might be due to the words just not being present in the model's vocabulary! Remember you can check this with the vocabularies you created, e.g. `"friterade" in src_vocab`. You could try increasing the vocabulary size and see if the results improve, but this will also increase training time.
#
# Finally, keep in mind that both the dataset and the model itself is quite tiny, as it's optimized for speed and demonstration purposes rather than efficiency!

# %%
translator.translate(['jag saknar min familj . ', 'stäng av vattnet .', 'jag älskar friterade bananer .'])
# Out:
# ['i miss my family .', 'close the gate .', 'i love bananas two weeks .']

# %% [markdown]
# # Part 4: Visualising attention

# %% [markdown]
# Figure&nbsp;3 in the paper by [Bahdanau et al. (2015)](https://arxiv.org/abs/1409.0473) shows some heatmaps of attention weights in selected sentences. In the last problem of this lab, we ask you to inspect attention weights for your trained translation system. We define a function `plot_attention` that visualises the attention weights. The *x*-axis corresponds to the words in the source sentence (Swedish) and the *y*-axis to the generated target sentence (English).
#
# The heatmap colours represent the **strengths of the attention weights**, with _lighter_ cells indicating a _higher_ attention value, just as in the Bahdanau et al. paper.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %config InlineBackend.figure_format = 'svg'

plt.style.use('seaborn-v0_8-whitegrid')

def plot_attention(translator, sentence):
    translation, weights = translator.translate_with_attention([sentence])[0]
    weights = np.array(weights)

    fig, ax = plt.subplots()
    heatmap = ax.pcolor(weights, cmap='Blues_r', vmin=0., vmax=1.)

    ax.xaxis.tick_top()
    ax.set_xticks(np.arange(weights.shape[1]) + 0.5, minor=False)
    ax.set_yticks(np.arange(weights.shape[0]) + 0.5, minor=False)
    ax.set_xticklabels(sentence.split(), minor=False, rotation=40)
    ax.set_yticklabels(translation.split(), minor=False)
    ax.invert_yaxis()

    plt.colorbar(heatmap)

# %% [markdown]
# Here is an example.

# %%
plot_attention(translator, 'jag saknar min familj . ')

# %% [markdown]
# #### 🤔 Task 7: Use these heatmaps to inspect the attention patterns for selected Swedish sentences
#
# Try to find sentences for which the model produces reasonably good English translations. If you don't speak Swedish, use sentences from the validation data. It might be interesting to look at examples where the Swedish and the English word order differ substantially.
#
# Based on your exploration, **answer the following questions:**
#
# - What sentences did you try out? What patterns did you spot? Include example heatmaps in your notebook.
# - Based on what you know about attention, did you expect your results? Was there anything surprising in them?

# %%
translator.translate(['hur mår du . ', 'jag älskar äpple . ', 'jag heter erik . ', 'går det bra . ', 
                      'kan du svenska ? ', 'kan du hjälpa mig ? ', 'kan du hjälpa mig med den här ? ',
                      'jag är trött .'])
# Out:
# ['how old you are injured .',
#  'i love him .',
#  'i just met her <unk> .',
#  'good .',
#  'can you do this ?',
#  'can you help me ?',
#  'can you help me carry ?',
#  "i ' m tired ."]

# %%
plot_attention(translator, 'jag är trött .')

# %%
plot_attention(translator, 'kan du hjälpa mig ? ')

# %% [markdown]
# **🥳 Congratulations on finishing this lab! 🥳**
